# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("vgsales.csv")
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.size
# Out:
# 182578

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.describe().T
# Out:
#                 count         mean          std      min      25%      50%  \
# Rank          16598.0  8300.605254  4791.853933     1.00  4151.25  8300.50
# Year          16327.0  2006.406443     5.828981  1980.00  2003.00  2007.00
# NA_Sales      16598.0     0.264667     0.816683     0.00     0.00     0.08
# EU_Sales      16598.0     0.146652     0.505351     0.00     0.00     0.02
# JP_Sales      16598.0     0.077782     0.309291     0.00     0.00     0.00
# Other_Sales   16598.0     0.048063     0.188588     0.00     0.00     0.01
# Global_Sales  16598.0     0.537441     1.555028     0.01     0.06     0.17
#
#                    75%       max
# Rank          12449.75  16600.00
# Year           2010.00   2020.00
# NA_Sales          0.24     41.49
# EU_Sales          0.11     29.02
# JP_Sales          0.04     10.22
# Other_Sales       0.04     10.57
# Global_Sales      0.47     82.74

# %% [markdown]
# ### By analysing the data we can say that the data is having outliers, the difference in mean and median shows how the data is reflected with outliers

# %%
sns.boxplot(data=df,x='Global_Sales')
# Out:
# <Axes: xlabel='Global_Sales'>

# %%
df['Publisher'].value_counts().head(10)
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
# THQ                              715
# Nintendo                         703
# Sony Computer Entertainment      683
# Sega                             639
# Take-Two Interactive             413
# Name: Publisher, dtype: int64

# %% [markdown]
# #### There are different Publishers around the world , Well Mentioned above are the Top 10 most game published Publishers

# %%
df['Year'].value_counts().head(10)
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1259
# 2007.0    1202
# 2011.0    1139
# 2006.0    1008
# 2005.0     941
# 2002.0     829
# 2003.0     775
# 2004.0     763
# Name: Year, dtype: int64

# %% [markdown]
# #### In 2009 were the most number of game was released which is 1431

# %% [markdown]
# ## sales over time

# %%
sns.countplot(data=df,x='Year')
plt.xticks(rotation=90)
plt.show()

# %%
yeargp=df.groupby('Year')

# %%
sy=yeargp['Global_Sales'].sum()
sy
# Out:
# Year
# 1980.0     11.38
# 1981.0     35.77
# 1982.0     28.86
# 1983.0     16.79
# 1984.0     50.36
# 1985.0     53.94
# 1986.0     37.07
# 1987.0     21.74
# 1988.0     47.22
# 1989.0     73.45
# 1990.0     49.39
# 1991.0     32.23
# 1992.0     76.16
# 1993.0     45.98
# 1994.0     79.17
# 1995.0     88.11
# 1996.0    199.15
# 1997.0    200.98
# 1998.0    256.47
# 1999.0    251.27
# 2000.0    201.56
# 2001.0    331.47
# 2002.0    395.52
# 2003.0    357.85
# 2004.0    419.31
# 2005.0    459.94
# 2006.0    521.04
# 2007.0    611.13
# 2008.0    678.90
# 2009.0    667.30
# 2010.0    600.45
# 2011.0    515.99
# 2012.0    363.54
# 2013.0    368.11
# 2014.0    337.05
# 2015.0    264.44
# 2016.0     70.93
# 2017.0      0.05
# 2020.0      0.29
# Name: Global_Sales, dtype: float64

# %%
sy.plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ## Top Selling Games and Platforms

# %%
df['Platform'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
pub=df.groupby('Publisher')

# %%
ps=pub['Global_Sales'].sum().sort_values(ascending=False).head(10)
ps
# Out:
# Publisher
# Nintendo                        1786.56
# Electronic Arts                 1110.32
# Activision                       727.46
# Sony Computer Entertainment      607.50
# Ubisoft                          474.72
# Take-Two Interactive             399.54
# THQ                              340.77
# Konami Digital Entertainment     283.64
# Sega                             272.99
# Namco Bandai Games               254.09
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## Major selling Game Publisher

# %%
ps.plot(kind='pie',ylabel='Global sales',figsize=(50,6),autopct='%.2f%%')
# Out:
# <Axes: ylabel='Global sales'>

# %% [markdown]
# #### Nintendo holds the major market share aong the publishers

# %%
nin=pub['Genre'].get_group('Nintendo').value_counts()

# %%
nin.plot(kind='barh',ylabel="Genre",title="Genres of Nintendo",color='Purple',alpha=0.9)
# Out:
# <Axes: title={'center': 'Genres of Nintendo'}, ylabel='Genre'>

# %% [markdown]
# as the data says Nintendo has released more number of platform Genre games about 112 and still leading in sales too, well you know who else regret to play 'super mario bros'!!! One of the best platform game from Nintendo which made them the best

# %%
nin
# Out:
# Platform        112
# Role-Playing    106
# Misc            100
# Action           79
# Puzzle           74
# Sports           55
# Racing           37
# Adventure        35
# Strategy         32
# Simulation       29
# Shooter          26
# Fighting         18
# Name: Genre, dtype: int64

# %%
pub['Global_Sales'].get_group('Nintendo').mean()
# Out:
# 2.541337126600285

# %% [markdown]
# - Nintendo have an average of 2.54 million in the whole sales

# %% [markdown]
# ### Publishers who are poor in performance

# %%
psleast=pub['Global_Sales'].sum().sort_values().head(30)

# %%
psleast
# Out:
# Publisher
# Interworks Unlimited, Inc.    0.01
# Inti Creates                  0.01
# Epic Games                    0.01
# Otomate                       0.01
# Takuyo                        0.01
# Ongakukan                     0.01
# UIG Entertainment             0.01
# Media Entertainment           0.01
# Piacci                        0.01
# Boost On                      0.01
# EON Digital Entertainment     0.01
# Interchannel-Holon            0.01
# Ascaron Entertainment         0.01
# New World Computing           0.01
# Rain Games                    0.01
# Michaelsoft                   0.01
# Naxat Soft                    0.01
# Genterprise                   0.01
# Paradox Development           0.01
# Commseed                      0.01
# Stainless Games               0.01
# Plenty                        0.02
# King Records                  0.02
# Karin Entertainment           0.02
# RED Entertainment             0.02
# Phoenix Games                 0.02
# ...

# %% [markdown]
# #### These are the the least selling publishers

# %% [markdown]
# ### Global sales chart of major publisher and Genre

# %%
gen=df.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=False).head(10)

# %%
import math
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.55,0.55,0.3,0.3])
axes1.plot(ps,'b-')
axes2.plot(gen,'y-.')
axes1.set_title('Publisher')
axes2.set_title('Genre')
plt.setp(axes1.xaxis.get_majorticklabels(), rotation=90)
plt.setp(axes2.xaxis.get_majorticklabels(), rotation=90)
plt.show()

# %%
g=df[['Name','Global_Sales']].head(10)

# %%
g
# Out:
#                         Name  Global_Sales
# 0                 Wii Sports         82.74
# 1          Super Mario Bros.         40.24
# 2             Mario Kart Wii         35.82
# 3          Wii Sports Resort         33.00
# 4   Pokemon Red/Pokemon Blue         31.37
# 5                     Tetris         30.26
# 6      New Super Mario Bros.         30.01
# 7                   Wii Play         29.02
# 8  New Super Mario Bros. Wii         28.62
# 9                  Duck Hunt         28.31

# %%
plt.figure(figsize=(8,6))
plt.barh(g['Name'],g['Global_Sales'],color='aqua',alpha=1)
plt.xlabel('Games')
plt.ylabel('Global Sales')
plt.title('Major Marketting Games')
plt.show()

# %% [markdown]
# ### Genre Analysis

# %%
Genre=df['Genre'].value_counts()

# %%
Genre.plot(kind='barh',color='green',alpha=.9)
# Out:
# <Axes: >

# %% [markdown]
# #### Action Genre have the highest popularity in games also on other hand puzzle is the least popular, well puzzles you know how popular they will be right??

# %% [markdown]
# ### Genre Sales around the world

# %% [markdown]
# #### we all know most of the game published is action as you know gamers do like action more than others so what about the sales ... lets check

# %%
gen
# Out:
# Genre
# Action          1751.18
# Sports          1330.93
# Shooter         1037.37
# Role-Playing     927.37
# Platform         831.37
# Misc             809.96
# Racing           732.04
# Fighting         448.91
# Simulation       392.20
# Puzzle           244.95
# Name: Global_Sales, dtype: float64

# %% [markdown]
# #### well as we can see that action is the popular one and so it holds the top position in sales too

# %%
gen.plot(kind='pie',figsize=(8,8),ylabel='Global Sales',autopct='%.2f%%')
# Out:
# <Axes: ylabel='Global Sales'>

# %% [markdown]
# about the quarter of the whole sales is holding by Action genre!!!
# well who else dont like them, ohh yaa there others too but for gamers atleast one of their gamne will be of action Genre

# %% [markdown]
# #### so what about genre sales in different regions

# %% [markdown]
# ### Regional Analysis

# %%
genjp=df.groupby('Genre')['JP_Sales'].sum()
genna=df.groupby('Genre')['NA_Sales'].sum()
geneu=df.groupby('Genre')['EU_Sales'].sum()
genot=df.groupby('Genre')['Other_Sales'].sum()

# %%
genjp
# Out:
# Genre
# Action          159.95
# Adventure        52.07
# Fighting         87.35
# Misc            107.76
# Platform        130.77
# Puzzle           57.31
# Racing           56.69
# Role-Playing    352.31
# Shooter          38.28
# Simulation       63.70
# Sports          135.37
# Strategy         49.46
# Name: JP_Sales, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.plot(genjp, label='JP_Sales',linestyle='-', marker='o', color='blue')
plt.plot(genna, label='NA_Sales',linestyle='--', marker='h', color='green')
plt.plot(geneu, label='EU_Sales',linestyle='-.', marker='D', color='magenta')
plt.plot(genot, label='Other_Sales',linestyle=':', marker='D', color='yellow')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.title("Different genre Sales Across the world")
plt.xlabel("Genre")
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### From Above Grapgh it is clear that most of the sale is contributed from North America, it holds a record of top action Genre games sele

# %% [markdown]
# #### How about the platform!!

# %%
plfm=df.groupby('Platform')

# %%
plfmg=plfm['Global_Sales'].sum().sort_values(ascending=False).head(10)

# %%
plfmg
# Out:
# Platform
# PS2     1255.64
# X360     979.96
# PS3      957.84
# Wii      926.71
# DS       822.49
# PS       730.66
# GBA      318.50
# PSP      296.28
# PS4      278.10
# PC       258.82
# Name: Global_Sales, dtype: float64

# %%
plfmg.plot(kind='bar')
# Out:
# <Axes: xlabel='Platform'>

# %% [markdown]
# #### it is clear from the graph that top selling platform position is hold by Play station 2 with a sale of 1255

# %% [markdown]
# ### Different regional sales on different platform

# %%
plfmj=plfm['JP_Sales'].sum()
plfme=plfm['EU_Sales'].sum()
plfmn=plfm['NA_Sales'].sum()
plfmo=plfm['Other_Sales'].sum()

# %%
plt.figure(figsize=(10, 6))
plt.plot(plfmj, label='JP_Sales',linestyle='-', marker='o', color='blue')
plt.plot(plfmn, label='NA_Sales',linestyle='--', marker='h', color='green')
plt.plot(plfme, label='EU_Sales',linestyle='-.', marker='D', color='magenta')
plt.plot(plfmo, label='Other_Sales',linestyle=':', marker='D', color='yellow')
plt.xticks(rotation=90)
plt.legend()
plt.grid(True)
plt.title("Different Platform sales Across the World")
plt.xlabel("Genre")
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# #### analysisng regional sales of platform we got to finalise that North America holds the record as we have discussed above that NA has sold most of the games and now it is same in case of platform too
# #### We can conclude that North America has contributed most sales in gaming all around the world

# %% [markdown]
# ### Relation Among The Regional Sales

# %%
plt.figure(figsize=(10,4))
sns.heatmap(df.corr(),annot=True,cmap='Greens',fmt='.2f',linewidths=1)
plt.show()

# %% [markdown]
# #### From the abve Heatmap it is clear the NA sale holds the best relation with Global sales and comes Europe Sale. Hence, we can confirm that North America and europe have higher sale contribution in the world

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Nintendo Publisher of japan have the highest sale contribution which is 28.55% in the period of 1980-2020
# - Nintendo Realeased 703 games in this period of time
# - Checking the records on sale we finalise that North america holds the recrd in marketting on the other hand
#   japan  made these games who shows poor performance which easily conclude that they are still in developping more
#   and more while we get addicted to their Games
# - starting from 2000 the market of games where at their peak mainly in the year of 2008 Global sales was 611.13
# - While checking the year 2020 both the production and distribution have faceds challenge such as:
#   *Economic uncertainties and challenges during the pandemic might have influenced consumer spending habits.
#    Some individuals might have reduced discretionary spending on non-essential items, including video games.
#   *The saturation of the market may impact the market share of individual companies or platforms.
#   *The gaming industry was in a transition period in 2020 with the release of next-gen gaming consoles like
#    PlayStation 5 and Xbox Series X/S. The transition to new hardware can sometimes lead to a temporary decline
#    in overall sales as consumers wait for more game titles and features to be released on the new platforms.
# - In the period between 1980-2020 a number of platform was introduced and in these time Playstation 2 holds
#   the top record in market with a Global sales of 1255.64. 2161 games have released in PS2 platform, one of the
#   best gaming console
# - You like Action games Right?? well who doesn't, there are a number of Genre in Games,looking from the year of       1980-2020 Action Games holds with a record of 20.59% of Total Sale. It is clear, In case of a gamer it is a must    to try those.Action games typically focus on  physical challenges that require hand-eye coordination, reflexes,     and quick decision-making.
#
# Hope you have find my analysis informative, Thank you for Reading.
# Do connect and check out my other works,
# GitHub: https://github.com/Rashid9226
